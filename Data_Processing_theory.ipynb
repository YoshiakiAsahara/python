# %% [markdown]
# <a href="https://colab.research.google.com/github/YoshiakiAsahara/python_learning_memo/blob/main/Data_Processing_theory.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **なぜデータ加工が必要なのか**
# データ加工はデータ分析や機会学習を行うために使うデータを適切な形式にととのえることをいう。欠損地処理、外れ値の処理、カテゴリ変数のエンコーディング等
# データ取得->データ加工->適切な形式へ

# %% [markdown]
# **データの種類と読み込み**

# %%
import pandas as pd

# %%
from google.colab import files
# ファイルをアップロード
uploaded = files.upload()

# Excelファイルを読み込む
df = pd.read_excel('FEH_00200524_240514005332.csv', index_col=0)
# Out:
#      <input type="file" id="files-75626bcc-d99f-454a-a623-1c25b8d5a2d8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-75626bcc-d99f-454a-a623-1c25b8d5a2d8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# **open()関数で読み込み**

# %%
with open('/content/FEH_00200524_240514005332.csv', 'r', encoding='cp932') as f:
  for i, row in enumerate(f):
    for col in row.strip().split(","):
        print(col, end='l')
    print()
    print("===")
    if i > 1:
        break
# Out:
# "統計名："l"人口推計 各月1日現在人口 概算値"l
# ===
# "表番号："l"001"l
# ===
# "表題："l"[概算値] 年齢（５歳階級），男女，月別人口－総人口（各月１日現在）-令和２年国勢調査基準-"l
# ===

# %% [markdown]
# **Pandasで読み込み**

# %%
import pandas as pd
df = pd.read_csv("/content/FEH_00200524_240514005332.csv", encoding='cp932',header = 11)

# %%
df.head()
# Out:
#    001  人口【万人】  001.1  総人口  01  概算値  00000  全国  2021001212  2021年12月  01002  \
# 0    1  人口【万人】      1  総人口   1  概算値      0  全国  2021001212  2021年12月   1003
# 1    1  人口【万人】      1  総人口   1  概算値      0  全国  2021001212  2021年12月   1004
# 2    1  人口【万人】      1  総人口   1  概算値      0  全国  2021001212  2021年12月   1005
# 3    1  人口【万人】      1  総人口   1  概算値      0  全国  2021001212  2021年12月   1006
# 4    1  人口【万人】      1  総人口   1  概算値      0  全国  2021001212  2021年12月   1007
#
#      5～9歳  Unnamed: 12  503  258  245
# 0  10～14歳          NaN  535  274  261
# 1  15～19歳          NaN  559  287  272
# 2  20～24歳          NaN  626  320  306
# 3  25～29歳          NaN  639  328  311
# 4  30～34歳          NaN  654  334  320
